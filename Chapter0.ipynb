# %%
# 0.4 Computer problems
import math
from mpmath import *

# Question 1
def equation1():
    x = [0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001,0.0000001, 0.00000001, 0.000000001,0.0000000001, 0.00000000001, 0.000000000001,0.0000000000001,0.00000000000001]
    print("x \t \t \t results")
    for i in x:
        function = (1-(1-i)**3)/(i)
        print(i, "\t \t \t", function)
    
def equation2():
    x = [0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001,0.0000001, 0.00000001, 0.000000001,0.0000000001, 0.00000000001, 0.000000000001,0.0000000000001,0.00000000000001]
    print("x \t \t \t results")
    for i in x:
        function = (1-sec(i))/(tan(i)**2)
        print(i, "\t \t \t", function)

equation1()

equation2()
    
# Question 2
def equation3():
    x = [0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001,0.0000001, 0.00000001, 0.000000001,0.0000000001, 0.00000000001, 0.000000000001,0.0000000000001,0.00000000000001]
    print("x \t \t \t results")
    for i in x:
        function=(tan(i)-i)/(i**3)
        print(i, "\t \t \t", function)

equation3()
    
# Question 3
a = -12345678987654321
b = 123

def solve(a,b):
    c = a**2+b**2
    result = (a) + (math.sqrt(c))
    print("The result for solve1 is: " "%.4f" %result)
    
solve(a,b)

# Question 4
c = 246886422468
d = 13579

def solve2(c,d):
    e = c**2+d
    result = (math.sqrt(e)) - (c)
    print("The result for solve2 is: " "%.4f" %result)

solve2(c,d)
# Out:
# x 	 	 	 results
# 0.1 	 	 	 2.709999999999999
# 0.01 	 	 	 2.9700999999999977
# 0.001 	 	 	 2.997000999999999
# 0.0001 	 	 	 2.9997000100001614
# 1e-05 	 	 	 2.9999700000837843
# 1e-06 	 	 	 2.99999700004161
# 1e-07 	 	 	 2.999999698660716
# 1e-08 	 	 	 2.999999981767587
# 1e-09 	 	 	 2.9999999151542056
# 1e-10 	 	 	 3.000000248221113
# 1e-11 	 	 	 3.000000248221113
# 1e-12 	 	 	 2.9999336348396355
# 1e-13 	 	 	 3.000932835561798
# 1e-14 	 	 	 2.9976021664879227
# x 	 	 	 results
# 0.1 	 	 	 -0.498747913711435
# 0.01 	 	 	 -0.499987499790956
# 0.001 	 	 	 -0.499999875014289
# 0.0001 	 	 	 -0.499999993627931
# 1e-05 	 	 	 -0.500000041336852
# 1e-06 	 	 	 -0.500044450290837
# 1e-07 	 	 	 -0.510702591327569
# 1e-08 	 	 	 0.0
# 1e-09 	 	 	 0.0
# 1e-10 	 	 	 0.0
# 1e-11 	 	 	 0.0
# 1e-12 	 	 	 0.0
# 1e-13 	 	 	 0.0
# 1e-14 	 	 	 0.0
# x 	 	 	 results
# 0.1 	 	 	 0.334672085450544
# 0.01 	 	 	 0.333346667207024
# 0.001 	 	 	 0.333333466731589
# 0.0001 	 	 	 0.333333336518908
# ...
